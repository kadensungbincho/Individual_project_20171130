# %%
from config.config_20171221 import DEFAULTS

# %%
from config.config_20171221 import DEFAULTS

from csv_to_query_list import get_query_list
from naver_api_requests import get_api_dictlist
from preprocess import preprocess
from mongodb import save_to_mongodb


# TARGET_BRAND_CSV_FP = str(input("TARGET_BRAND_CSV_FP : "))
# TARGET_INFRA_CSV_FP = str(input("TARGET_INFRA_CSV_FP : "))
# TARGET_SIDO_GUGUN_DONG_CSV_FP = str(input("TARGET_SIDO_GUGUN_DONG_CSV_FP : "))
# API_ID = str(input("API_ID : "))
# API_SECRET = str(input("API_SECRET : "))
# MONGODB_USERNAME = str(input("MONGODB USERNAME : "))
# MONGODB_PASSWORD = str(input("MONGODB PASSWORD : "))

TARGET_BRAND_CSV_FP = DEFAULTS['TARGET_BRAND_CSV_FP']
TARGET_INFRA_CSV_FP = DEFAULTS['TARGET_INFRA_CSV_FP']
TARGET_SIDO_GUGUN_DONG_CSV_FP = DEFAULTS['TARGET_SIDO_GUGUN_DONG_CSV_FP']
MONGODB_USERNAME = DEFAULTS['MONGODB_USERNAME']
MONGODB_PASSWORD = DEFAULTS['MONGODB_PASSWORD']
MONGODB_DBNAME = DEFAULTS['MONGODB_DBNAME']

# %%
from api_requests import GetQuery
sample = GetQuery(TARGET_SIDO_GUGUN_DONG_CSV_FP, TARGET_BRAND_CSV_FP)

# %%
a = pd.read_csv('./csv_input/brand_20171221.csv').astype('object').values.flatten()
for i in a:
    print(i)

# %%
len(sample.final_query_lists_bygugun)

# %%
blist, ilist = get_query_list(TARGET_SIDO_GUGUN_DONG_CSV_FP, TARGET_BRAND_CSV_FP, TARGET_INFRA_CSV_FP)

# %%
len(np.unique(blist))

# %%
pd.read_csv('./dsmaf.csv')

# %%
blist

# %%
len(blist)

# %%
len(ilist)

# %%
len(np.unique(ilist))

# %%
a = pd.DataFrame({
    'a': ['a', 'b'],
    'b': ['a', 'b']
})

# %%
a

# %%
(a['a'] + ' ' + a['b']).values

# %%
aaa = np.array([['a'], ['b'], ['c']], dtype='object')

# %%
aaa + ' a'

# %%
(a['a'] + ' ' + a['b']).values

# %%
for i in a.astype('object').values.flatten():
    print(i)

# %%
from api_requests import GetQuery
GetQuery()

# %%
g = train_df.groupby('species')['id'].apply(list)
g

# %%
[' '.join(i) for i in a.values]

# %%
' '.join(a.values

# %%
np.apply_along_axis(lambda x : ' '.join(x), 1, a)

# %%
    'API_ID' : [
        '6MDkAOqz2_LTCSJxe7z9', 
        'TQLUfAMmGIq7o7ax4O5G', 
        'QnMrbbB_iCeVAKf8L0OT', 
        'aIupKzB__UU93OFuGD6b', 
        'iNuroJPuZQwULrg2GMEx'],
    'API_SECRET' : [
        '7kW3XNFzXj', 
        'AHhQozW528', 
        'jgcsi81U6V', 
        'ZoxUT5tuCR', 
        'yNfQepqaLh']

# %%
from api_requests import NaverRequests
sample1 = NaverRequests('6MDkAOqz2_LTCSJxe7z9', '7kW3XNFzXj', ['서울 마포구 유니클로', '서울 강남구 유니클로'], 10)

# %%
category_query_dictlist = sample1.get_category_query

# %%
from re_preprocess import Preprocess

# %%
sample_preprocess = Preprocess('유니클로', category_query_dictlist)

# %%
sample_preprocess.preprocess()

# %%
a = np.array([[1, 2, 3]])

# %%
temp_loc_df = pd.read_csv('./csv_input/sido_gugun_dong_20171221.csv').loc[:, ['sido', 'gugun']]
local_query_array = np.apply_along_axis(lambda x : ' '.join(x), 1, temp_loc_df.values).astype('object')

# %%
class GetQuery(object):
    def __init__(self, loc_fp, cat_fp):
        self.loc_fp = loc_fp
        self.cat_fp = cat_fp
        
    def get_local_query_array(self, fp):
        try:
            temp_loc_df = pd.read_csv(fp).loc[:, ['sido', 'gugun']]
            local_query_array = np.apply_along_axis(lambda x : ' '.join(x), 1, temp_loc_df.values).astype('object')    
        except:
            raise FileNotFoundError("{} does not exists".format(fp))
        return local_query_array        
    
    def get_category_query_array(self, fp):
        try:
            categories_query_array = pd.read_csv(fp).astype('object').values.flatten()
        except:
            raise FileNotFoundError("{} does not exists".format(fp))
        return categories_query_array
     
    def get_final_query_dict_bygugun(self):
        local_query_array = self.get_local_query_array(self.loc_fp)
        categories_query_array = self.get_category_query_array(self.cat_fp)
        final_query_dict_bygugun = {}
        for category in categories_query_array:
            local_category_query_array = local_query_array + ' ' + category
            final_query_dict_bygugun[category] = list(local_category_query_array)
        return final_query_dict_bygugun

# %%
# from re_query import GetQuery
query_dict = GetQuery('./csv_input/sido_gugun_dong_20171221.csv', './csv_input/brand_20171221.csv').get_final_query_dict_bygugun()

# %%
def get_local_query_array(fp):
    try:
        temp_loc_df = pd.read_csv(fp).loc[:, ['sido', 'gugun']].drop_duplicates()
        local_query_array = np.apply_along_axis(lambda x : ' '.join(x), 1, temp_loc_df.values).astype('object')    
    except:
        raise FileNotFoundError("{} does not exists".format(fp))
    return local_query_array

# %%
loc_arr = get_local_query_array('./csv_input/sido_gugun_dong_20171221.csv')

# %%
loc_arr
# Out:
# array(['서울특별시 종로구', '서울특별시 중구', '서울특별시 용산구', '서울특별시 성동구', '서울특별시 광진구',
#        '서울특별시 동대문', '서울특별시 중랑구', '서울특별시 성북구', '서울특별시 강북구', '서울특별시 도봉구',
#        '서울특별시 노원구', '서울특별시 은평구', '서울특별시 서대문', '서울특별시 마포구', '서울특별시 양천구',
#        '서울특별시 강서구', '서울특별시 구로구', '서울특별시 금천구', '서울특별시 영등포', '서울특별시 동작구',
#        '서울특별시 관악구', '서울특별시 서초구', '서울특별시 강남구', '서울특별시 송파구', '서울특별시 강동구'], dtype=object)

# %%
query_dict['씨유']
# Out:
# ['서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 성동구 씨유',
#  '서울특별시 성동구 씨유',
#  '서울특별시 성동구 씨유',
#  '서울특별시 성동구 씨유',
#  '서울특별시 성동구 씨유',
# ...

# %%
a, b= get_api_id_secret(i)

# %%
a
# Out:
# '6MDkAOqz2_LTCSJxe7z9'

# %%
b
# Out:
# '7kW3XNFzXj'

# %%
key, val =list(query_dict.items())[0]

# %%
import pandas as pd
import numpy as np

import urllib.request
import json

from config.config_20171221 import DEFAULTS_API

import sys
import os
import time
import math

def get_single_query_page(api_id, api_secret, encQuery, display, start):
    url = "https://openapi.naver.com/v1/search/local.json?query={}&display={}&start={}".format(encQuery, display, start)
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", api_id)
    request.add_header("X-Naver-Client-Secret", api_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()    
    if(rescode==200):
        response_body = response.read()
        return json.loads(response_body.decode('utf-8'))
    else:
        return None
    
def get_single_query(api_id, api_secret, local_category_query, display):
    encQuery = urllib.parse.quote(local_category_query)

    # check total result to set total trial number
    check_total_dict = get_single_query_page(
        api_id, api_secret, encQuery, display, 1)
    total_num = check_total_dict['total']

    # get total trial number with ceil
    total_trial = int(math.ceil(total_num/display))  

    # get all results for a single query as dicts in a list
    count = 0
    single_query_result_dictlist = []
    for trial_num in range(1, total_trial+1):
        start = display * (trial_num-1) + 1
        try:
            temp_dict = get_single_query_page(
                    api_id, api_secret, encQuery, display, start)
            single_query_result_dictlist.extend(temp_dict['items'])
            count += 1
        except:
             pass
    return single_query_result_dictlist

# %%
get_single_query(a, b, val[0], 10)
# Out:
# [{'address': '서울특별시 종로구 명륜4가 187',
#   'category': '생활,편의>편의점',
#   'description': '도시락, 생활용품, 음료수 등 제품 판매.',
#   'link': 'http://cu.bgfretail.com/',
#   'mapx': '311776',
#   'mapy': '553859',
#   'roadAddress': '서울특별시 종로구 창경궁로 236 이화빌딩',
#   'telephone': '02-742-7897',
#   'title': 'CU 명륜성대점'},
#  {'address': '서울특별시 종로구 종로1가 24 르메이에르종로타운 109-2호',
#   'category': '생활,편의>편의점',
#   'description': '24시간 편의점, 택배 접수 가능 지점.',
#   'link': 'http://cu.bgfretail.com/',
#   'mapx': '310063',
#   'mapy': '552585',
#   'roadAddress': '서울특별시 종로구 종로 19 르메이에르종로타운1',
#   'telephone': '02-2075-5537',
#   'title': 'CU 종로1가점'},
#  {'address': '서울특별시 종로구 효자동 70-1',
#   'category': '생활,편의>편의점',
#   'description': '24시간 편의점, 택배 접수 가능 지점.',
#   'link': 'http://cu.bgfretail.com/',
#   'mapx': '309285',
#   'mapy': '553960',
#   'roadAddress': '서울특별시 종로구 자하문로 82',
#   'telephone': '02-725-8923',
#   'title': 'CU 종로효자점'},
#  {'address': '서울특별시 종로구 내자동 61-1',
#   'category': '생활,편의>편의점',
# ...

# %%
def get_category_query(api_id, api_secret, local_category_query, display):
    category_query_dictlist = []
    for local_category_query in val[:5]:
        temp_single_query_result_dictlist = get_single_query(
                                        api_id = api_id,
                                        api_secret = api_secret,
                                        local_category_query = local_category_query, 
                                        display = display
                                        )
        category_query_dictlist.extend(temp_single_query_result_dictlist)
    return category_query_dictlist

# %%
len(get_category_query(a, b, val, 10))
# Out:
# 2070

# %%
val
# Out:
# ['서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 종로구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 중구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 용산구 씨유',
#  '서울특별시 성동구 씨유',
#  '서울특별시 성동구 씨유',
#  '서울특별시 성동구 씨유',
#  '서울특별시 성동구 씨유',
#  '서울특별시 성동구 씨유',
# ...
